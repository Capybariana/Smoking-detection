# %%
import os, sys
import cv2
import numpy as np
from PIL import Image
from ultralytics import YOLO
from openpifpaf import predict
from typing import List, Tuple, Dict, Any
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import math

import logging

# Устанавливаем уровень логирования на ERROR, чтобы не выводились информационные сообщения
logging.getLogger().setLevel(logging.ERROR)

# %%
class YoloDetector:
    def __init__(self, model_path='yolov8n.pt'):
        self.model = YOLO(model_path, verbose=False)  # Используется YOLOv8

    def detect_and_crop(self, image, annotations, image_size):
        results = self.model(image)
        boxes = results[0].boxes
        people_images = []

        for i in range(len(boxes)):
            cls = int(boxes.cls[i].item())
            if cls == 0:  # человек
                x1, y1, x2, y2 = boxes.xyxy[i].tolist()
                x1, y1 = int(max(x1, 0)), int(max(y1, 0))
                x2, y2 = int(min(x2, image_size[1])), int(min(y2, image_size[0]))

                matched_class = None
                for class_id, xc, yc, w, h in annotations:
                    abs_xc = xc * image_size[1]
                    abs_yc = yc * image_size[0]

                    if x1 <= abs_xc <= x2 and y1 <= abs_yc <= y2:
                        matched_class = class_id
                        break

                if matched_class is not None:
                    cropped = image[y1:y2, x1:x2]
                    bbox = [x1, y1, x2, y2]
                    people_images.append((cropped, bbox, matched_class))

        return people_images


def read_annotations(label_path):
    annotations = []
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) == 5:
                    class_id = int(parts[0])
                    x_center, y_center, w, h = map(float, parts[1:])
                    annotations.append((class_id, x_center, y_center, w, h))
    return annotations

def detect_keypoints_openpifpaf(image):
    """Detect human keypoints and return list of points (x, y, confidence)"""
    try:
        # Convert to PIL Image format
        image_pil = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        
        # Initialize predictor
        predictor = predict.Predictor(checkpoint='shufflenetv2k30')
        
        # Get predictions - обработка разных форматов возврата
        predictions = predictor.pil_image(image_pil)
        
        # Для разных версий OpenPifPaf
        if isinstance(predictions, tuple) and len(predictions) == 3:
            # Новые версии возвращают (predictions, _, _)
            predictions = predictions[0]
        
        keypoints_list = []
        
        if predictions:
            for pred in predictions:
                try:
                    # Способ 1: через атрибут .data (новые версии)
                    if hasattr(pred, 'data'):
                        kps = pred.data
                        points = [(float(kp[0]), float(kp[1]), float(kp[2])) for kp in kps]
                    # Способ 2: через атрибут .keypoints (старые версии)
                    elif hasattr(pred, 'keypoints'):
                        kps = pred.keypoints
                        points = [(float(kp[0]), float(kp[1]), float(kp[2])) for kp in kps]
                    else:
                        continue
                    
                    if len(points) == 17:  # Проверяем что получили 17 точек COCO
                        keypoints_list.append(points)
                except Exception as e:
                    print(f"Error processing prediction: {e}")
                    continue
        
        return keypoints_list
    
    except Exception as e:
        print(f"Keypoint detection failed: {e}")
        return []

# %%
def normalize_keypoints_relative_to_bbox(keypoints, bbox):
    """
    Нормализует ключевые точки относительно размера bbox.
    
    :param keypoints: Список из 17 ключевых точек (x, y, confidence).
    :param bbox: Bbox вида [x1, y1, x2, y2] для нормализации.
    
    :return: Список нормализованных ключевых точек.
    """
    x1, y1, x2, y2 = bbox
    bbox_width = x2 - x1
    bbox_height = y2 - y1

    norm_keypoints = []
    
    for (x, y, c) in keypoints:
        if x < 0 or y < 0 or c == 0:
            norm_x = 0
            norm_y = 0
        else:
            norm_x = x / bbox_width
            norm_y = y / bbox_height
        norm_keypoints.append([norm_x, norm_y, c])

    return norm_keypoints

# %%
class KeypointsDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transform=None):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.image_files = [f for f in os.listdir(images_dir) if f.endswith('.jpg') or f.endswith('.png')]
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        # Загружаем изображение
        image_name = self.image_files[idx]
        image_path = os.path.join(self.images_dir, image_name)
        image = cv2.imread(image_path)
        image_size = image.shape[:2]  # (height, width)

        # Чтение аннотаций
        label_path = os.path.join(self.labels_dir, image_name.replace('.jpg', '.txt').replace('.png', '.txt'))
        annotations = read_annotations(label_path)

        # Детекция и обрезка людей
        yolo_detector = YoloDetector('yolov8n.pt')
        people_images = yolo_detector.detect_and_crop(image, annotations, image_size)

        # Для каждого человека, нормализуем keypoints
        dataset_entry = []
        for cropped_image, bbox, class_id in people_images:
            keypoints = detect_keypoints_openpifpaf(cropped_image)
            if keypoints:  # Если есть ключевые точки
                norm_keypoints = normalize_keypoints_relative_to_bbox(keypoints[0], bbox)  # Нормализуем только первые 17 точек
                dataset_entry.append({
                    'image': image,
                    'class_id': class_id,
                    'bbox': bbox,
                    'keypoints': norm_keypoints
                })

        # Применяем преобразования (если нужны)
        if self.transform:
            # Тут можно добавить преобразования для изображения (например, преобразование в тензор)
            image = self.transform(image)

        return dataset_entry

# %%
images_dir = 'dataset/images'
labels_dir = 'dataset/labels'
dataset = KeypointsDataset(images_dir, labels_dir)

# %%
# Разделение на обучающий и тестовый датасеты
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

print(f'Обучающий набор: {len(train_dataset)} изображений')
print(f'Тестовый набор: {len(test_dataset)} изображений')
# Out:
# Обучающий набор: 490 изображений
# Тестовый набор: 123 изображений

# %%
def prepare_data_for_transformer(dataset):
    transformer_input = []
    target_labels = []  # Сюда собираем целевые метки class_id (курит/не курит/пауза)
    
    for sample in dataset:
        for person in sample:
            # Получаем данные
            class_id = person['class_id']  # Это целевая метка
            bbox = np.array(person['bbox'], dtype=np.float32)  # Преобразуем в тензор
            keypoints = np.array(person['keypoints'], dtype=np.float32).flatten()  # Преобразуем в 1D массив
            
            # Строим последовательность признаков для трансформера
            input_sequence = np.concatenate([ 
                bbox,                 # bbox (4 признака)
                keypoints             # keypoints (34 признака)
            ])
            
            transformer_input.append(torch.tensor(input_sequence))
            target_labels.append(torch.tensor(class_id))  # Класс (0 - не курит, 1 - пауза, 2 - курит)
    
    return transformer_input, target_labels

# %%
class TransformerModel(nn.Module):
    def __init__(self, feature_dim, num_classes):
        super(TransformerModel, self).__init__()
        
        # Трансформер для обработки последовательности признаков
        self.transformer = nn.Transformer(
            d_model=feature_dim,  # Размерность признаков (bbox + keypoints)
            nhead=11,  # Количество голов в multihead attention
            num_encoder_layers=6,  # Количество слоев энкодера
            num_decoder_layers=6,  # Количество слоев декодера
            batch_first=True  # Указываем, что данные будут в формате (batch_size, seq_len, feature_dim)
        )
        
        # Классификатор для предсказания класса
        self.fc = nn.Linear(feature_dim, num_classes)  # 3 класса (не курит, пауза, курит)

    def forward(self, x):
        # Прогоняем через трансформер
        x = self.transformer(x, x)  # (src, tgt)
        
        # Извлекаем только последний токен для классификации
        x = x[:, -1, :]
        
        # Прогоняем через классификатор
        out = self.fc(x)
        return out

# %%
train_inputs, train_labels = prepare_data_for_transformer(train_dataset)
test_inputs, test_labels = prepare_data_for_transformer(test_dataset)

train_inputs = torch.stack(train_inputs)  # (N, 55)
train_labels = torch.tensor(train_labels)
test_inputs = torch.stack(test_inputs)
test_labels = torch.tensor(test_labels)

train_inputs = train_inputs.unsqueeze(1)  # (N, 1, 55)
test_inputs = test_inputs.unsqueeze(1)

# Создаем датасеты и лоадеры
train_loader = DataLoader(TensorDataset(train_inputs, train_labels), batch_size=64, shuffle=True)
test_loader = DataLoader(TensorDataset(test_inputs, test_labels), batch_size=64, shuffle=False)
# Out:
# 0: 384x640 4 persons, 4 cars, 19.6ms
# Speed: 6.4ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserIn
# 0: 384x640 2 persons, 6 cars, 2 trucks, 14.4ms
# Speed: 1.1ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 8.7ms
# Speed: 1.2ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 14.2ms
# Speed: 1.2ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 9.0ms
# Speed: 1.1ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 12.8ms
# Speed: 1.1ms preprocess, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 9.4ms
# Speed: 1.2ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# fo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/
# 0: 384x640 2 persons, 7 cars, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 9.6ms
# Speed: 1.1ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 10.0ms
# Speed: 1.2ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 10.1ms
# Speed: 1.1ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.2ms
# Speed: 1.1ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 10.2ms
# Speed: 1.5ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 12.5ms
# Speed: 1.2ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 15.0ms
# Speed: 1.2ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 11.9ms
# Speed: 1.2ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 14.9ms
# Speed: 1.5ms preprocess, 14.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 14.6ms
# Speed: 1.2ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occup
# 0: 384x640 1 person, 6 cars, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 11.3ms
# Speed: 1.1ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 12.2ms
# Speed: 1.1ms preprocess, 12.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 13.7ms
# Speed: 1.3ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 16.6ms
# Speed: 1.6ms preprocess, 16.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp
# 0: 384x640 1 person, 2 cars, 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 12.7ms
# Speed: 1.2ms preprocess, 12.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 17.1ms
# Speed: 1.8ms preprocess, 17.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 13.0ms
# Speed: 1.5ms preprocess, 13.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 car, 1 fire hydrant, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 11.7ms
# Speed: 1.2ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 11.2ms
# Speed: 1.1ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 10.0ms
# Speed: 1.1ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 10.2ms
# Speed: 2.2ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# :102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/open
# 0: 384x640 1 person, 7 cars, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 19.6ms
# Speed: 1.4ms preprocess, 19.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 12.4ms
# Speed: 1.1ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 11.7ms
# Speed: 1.1ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 12.8ms
# Speed: 1.1ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 18.2ms
# Speed: 1.3ms preprocess, 18.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# pifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: re
# 0: 384x640 1 person, 6 cars, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 11.1ms
# Speed: 1.1ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 12.1ms
# Speed: 1.1ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 10.9ms
# Speed: 1.1ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 11.1ms
# Speed: 1.1ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 15.6ms
# Speed: 1.3ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 11.0ms
# Speed: 1.1ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 10.8ms
# Speed: 1.1ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 16.4ms
# Speed: 1.1ms preprocess, 16.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# sizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/sr
# 0: 384x640 1 person, 2 cars, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 12.2ms
# Speed: 1.2ms preprocess, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 10.4ms
# Speed: 1.2ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# c/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# ...
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo
# 0: 384x640 2 persons, 7 cars, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 19.2ms
# Speed: 1.4ms preprocess, 19.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 17.8ms
# Speed: 1.4ms preprocess, 17.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 13.0ms
# Speed: 1.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 15.2ms
# Speed: 1.3ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 fire hydrant, 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 14.4ms
# Speed: 1.2ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 11.9ms
# Speed: 1.2ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# : resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csr
# 0: 384x640 2 persons, 8 cars, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 13.4ms
# Speed: 1.2ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 11.0ms
# Speed: 1.1ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 11.0ms
# Speed: 1.1ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 10.0ms
# Speed: 1.2ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 17.6ms
# Speed: 1.4ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 11.3ms
# Speed: 1.2ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 15.2ms
# Speed: 1.2ms preprocess, 15.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 10.7ms
# Speed: 1.1ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# c/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr

# %%
model = TransformerModel(feature_dim=55, num_classes=3)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epochs = 100

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    
    for batch_x, batch_y in train_loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)

        optimizer.zero_grad()
        outputs = model(batch_x)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    avg_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")

model.eval()
correct = 0
total = 0

with torch.no_grad():
    for batch_x, batch_y in test_loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        outputs = model(batch_x)
        _, predicted = torch.max(outputs, 1)
        total += batch_y.size(0)
        correct += (predicted == batch_y).sum().item()

print(f"Точность на тесте: {100 * correct / total:.2f}%")
# Out:
# Epoch 1/100, Loss: 0.7560
# Epoch 2/100, Loss: 0.6534
# Epoch 3/100, Loss: 0.6440
# Epoch 4/100, Loss: 0.6294
# Epoch 5/100, Loss: 0.6064
# Epoch 6/100, Loss: 0.6040
# Epoch 7/100, Loss: 0.5909
# Epoch 8/100, Loss: 0.5683
# Epoch 9/100, Loss: 0.5538
# Epoch 10/100, Loss: 0.5408
# Epoch 11/100, Loss: 0.5520
# Epoch 12/100, Loss: 0.5452
# Epoch 13/100, Loss: 0.5494
# Epoch 14/100, Loss: 0.5365
# Epoch 15/100, Loss: 0.5323
# Epoch 16/100, Loss: 0.5171
# Epoch 17/100, Loss: 0.5211
# Epoch 18/100, Loss: 0.5379
# Epoch 19/100, Loss: 0.5098
# Epoch 20/100, Loss: 0.5160
# Epoch 21/100, Loss: 0.5225
# Epoch 22/100, Loss: 0.5275
# Epoch 23/100, Loss: 0.5174
# Epoch 24/100, Loss: 0.5043
# Epoch 25/100, Loss: 0.5144
# Epoch 26/100, Loss: 0.4968
# Epoch 27/100, Loss: 0.5200
# Epoch 28/100, Loss: 0.5025
# Epoch 29/100, Loss: 0.5037
# Epoch 30/100, Loss: 0.4914
# Epoch 31/100, Loss: 0.5084
# Epoch 32/100, Loss: 0.5052
# Epoch 33/100, Loss: 0.5041
# Epoch 34/100, Loss: 0.4883
# Epoch 35/100, Loss: 0.4852
# Epoch 36/100, Loss: 0.4994
# Epoch 37/100, Loss: 0.4951
# Epoch 38/100, Loss: 0.4985
# Epoch 39/100, Loss: 0.4954
# Epoch 40/100, Loss: 0.4835
# Epoch 41/100, Loss: 0.4883
# Epoch 42/100, Loss: 0.4831
# Epoch 43/100, Loss: 0.4968
# Epoch 44/100, Loss: 0.4904
# Epoch 45/100, Loss: 0.4869
# Epoch 46/100, Loss: 0.4777
# Epoch 47/100, Loss: 0.4739
# Epoch 48/100, Loss: 0.4844
# Epoch 49/100, Loss: 0.4934
# Epoch 50/100, Loss: 0.4874
# Epoch 51/100, Loss: 0.4826
# Epoch 52/100, Loss: 0.4801
# Epoch 53/100, Loss: 0.4954
# Epoch 54/100, Loss: 0.4917
# Epoch 55/100, Loss: 0.4744
# Epoch 56/100, Loss: 0.4771
# Epoch 57/100, Loss: 0.4837
# Epoch 58/100, Loss: 0.4805
# Epoch 59/100, Loss: 0.4763
# Epoch 60/100, Loss: 0.4763
# Epoch 61/100, Loss: 0.4747
# Epoch 62/100, Loss: 0.4690
# Epoch 63/100, Loss: 0.4775
# Epoch 64/100, Loss: 0.4684
# Epoch 65/100, Loss: 0.4684
# Epoch 66/100, Loss: 0.4689
# Epoch 67/100, Loss: 0.4810
# Epoch 68/100, Loss: 0.4539
# Epoch 69/100, Loss: 0.4782
# Epoch 70/100, Loss: 0.4792
# Epoch 71/100, Loss: 0.4666
# Epoch 72/100, Loss: 0.4439
# Epoch 73/100, Loss: 0.4533
# Epoch 74/100, Loss: 0.4375
# Epoch 75/100, Loss: 0.4510
# Epoch 76/100, Loss: 0.4497
# Epoch 77/100, Loss: 0.4633
# Epoch 78/100, Loss: 0.4401
# Epoch 79/100, Loss: 0.4714
# Epoch 80/100, Loss: 0.4545
# Epoch 81/100, Loss: 0.4562
# Epoch 82/100, Loss: 0.4619
# Epoch 83/100, Loss: 0.4452
# Epoch 84/100, Loss: 0.4631
# Epoch 85/100, Loss: 0.4768
# Epoch 86/100, Loss: 0.4781
# Epoch 87/100, Loss: 0.4552
# Epoch 88/100, Loss: 0.4415
# Epoch 89/100, Loss: 0.4394
# Epoch 90/100, Loss: 0.4443
# Epoch 91/100, Loss: 0.4257
# Epoch 92/100, Loss: 0.4370
# Epoch 93/100, Loss: 0.4199
# Epoch 94/100, Loss: 0.4194
# Epoch 95/100, Loss: 0.4378
# Epoch 96/100, Loss: 0.4309
# Epoch 97/100, Loss: 0.4151
# Epoch 98/100, Loss: 0.4148
# Epoch 99/100, Loss: 0.4208
# Epoch 100/100, Loss: 0.4118
# Точность на тесте: 78.57%

# %%
# Цвета для классов
CLASS_COLORS = {
    0: (0, 255, 0),    # Зеленый
    1: (0, 165, 255),  # Оранжевый (BGR)
    2: (0, 0, 255),    # Красный
}

CLASS_NAMES = {
    0: 'dont',
    1: 'pause',
    2: 'smoke',
}

def visualize_predictions(dataset, model, device='cpu', save_path=None):
    model.eval()
    model.to(device)

    for i, sample in enumerate(dataset):
        if not sample:
            print(f"[{i}] Пропущено: пустое изображение или нет людей")
            continue

        image = None

        for person in sample:
            if image is None:
                if 'image' not in person or person['image'] is None:
                    print(f"[{i}] Ошибка: нет изображения в sample")
                    continue
                image = person['image'].copy()

            bbox = person['bbox']
            keypoints = np.array(person['keypoints'], dtype=np.float32).flatten()
            input_tensor = np.concatenate([bbox, keypoints])
            input_tensor = torch.tensor(input_tensor, dtype=torch.float32).unsqueeze(0).unsqueeze(1).to(device)

            with torch.no_grad():
                output = model(input_tensor)
                pred_class = output.argmax(dim=1).item()

            # Цвет и подпись
            color = CLASS_COLORS.get(pred_class, (255, 255, 255))
            label = CLASS_NAMES.get(pred_class, str(pred_class))

            x1, y1, x2, y2 = map(int, bbox)
            cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
            cv2.putText(image, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        if image is not None:
            if save_path:
                cv2.imwrite(f"{save_path}/result_{i}.jpg", image)
            else:
                cv2.imshow("Prediction", image)
                cv2.waitKey(0)
        else:
            print(f"[{i}] Не удалось визуализировать — image is None")

    cv2.destroyAllWindows()

# %%
visualize_predictions(test_dataset, model, device='cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# 0: 384x640 1 person, 7 cars, 21.9ms
# Speed: 2.1ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 27.6ms
# Speed: 1.4ms preprocess, 27.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:
# 0: 384x640 2 persons, 7 cars, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 21.6ms
# Speed: 1.9ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [4] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 2 persons, 8 cars, 25.1ms
# Speed: 1.6ms preprocess, 25.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 13.4ms
# Speed: 2.3ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 14.7ms
# Speed: 1.2ms preprocess, 14.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 12.7ms
# Speed: 1.6ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 17.6ms
# Speed: 1.4ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 17.9ms
# Speed: 1.4ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 18.4ms
# Speed: 1.9ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 11.2ms
# Speed: 1.1ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 21.0ms
# Speed: 1.6ms preprocess, 21.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 19.0ms
# Speed: 1.9ms preprocess, 19.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 18.0ms
# Speed: 1.3ms preprocess, 18.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/op
# 0: 384x640 1 person, 6 cars, 18.1ms
# Speed: 1.4ms preprocess, 18.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 12.9ms
# Speed: 1.1ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [24] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 1 person, 6 cars, 23.2ms
# Speed: 1.9ms preprocess, 23.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 12.0ms
# Speed: 1.2ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [28] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 4 persons, 7 cars, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 17.6ms
# Speed: 1.3ms preprocess, 17.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 12.5ms
# Speed: 1.2ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [34] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 1 person, 7 cars, 17.6ms
# Speed: 1.4ms preprocess, 17.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 17.4ms
# Speed: 1.4ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 12.9ms
# Speed: 1.2ms preprocess, 12.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 17.3ms
# Speed: 1.6ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 12.3ms
# Speed: 1.4ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [40] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 1 person, 6 cars, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# enpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: re
# 0: 384x640 1 person, 1 car, 12.8ms
# Speed: 1.2ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 15.2ms
# Speed: 1.3ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 11.6ms
# Speed: 1.8ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [44] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 2 persons, 7 cars, 13.1ms
# Speed: 1.6ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 13.9ms
# Speed: 1.5ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 14.9ms
# Speed: 1.2ms preprocess, 14.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 13.4ms
# Speed: 1.2ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 14.8ms
# Speed: 1.2ms preprocess, 14.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# sizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/oc
# 0: 384x640 2 persons, 4 cars, 14.2ms
# Speed: 1.6ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 17.6ms
# Speed: 1.4ms preprocess, 17.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 22.0ms
# Speed: 1.4ms preprocess, 22.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 11.2ms
# Speed: 1.2ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 12.3ms
# Speed: 1.1ms preprocess, 12.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [66] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 7 cars, 12.4ms
# Speed: 1.1ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [67] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 6 persons, 4 cars, 13.8ms
# Speed: 1.4ms preprocess, 13.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 12.3ms
# Speed: 1.4ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 21.9ms
# Speed: 2.3ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 fire hydrant, 22.1ms
# Speed: 2.2ms preprocess, 22.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 20.6ms
# Speed: 1.9ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 19.2ms
# Speed: 1.4ms preprocess, 19.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 19.2ms
# Speed: 1.4ms preprocess, 19.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [75] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 2 persons, 7 cars, 19.3ms
# Speed: 1.4ms preprocess, 19.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 18.1ms
# Speed: 1.6ms preprocess, 18.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 18.2ms
# Speed: 1.4ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# cupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy b
# 0: 384x640 1 person, 7 cars, 12.3ms
# Speed: 1.2ms preprocess, 12.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 10.9ms
# Speed: 1.1ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 16.4ms
# Speed: 1.5ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 18.2ms
# Speed: 1.4ms preprocess, 18.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 16.9ms
# Speed: 1.8ms preprocess, 16.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# uffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102:
# 0: 384x640 3 persons, 6 cars, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 fire hydrant, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 17.3ms
# Speed: 1.3ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 17.4ms
# Speed: 1.4ms preprocess, 17.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 11.6ms
# Speed: 1.6ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 13.3ms
# Speed: 1.2ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [108] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 2 persons, 7 cars, 11.4ms
# Speed: 1.1ms preprocess, 11.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 14.1ms
# Speed: 1.5ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 12.1ms
# Speed: 1.1ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 17.8ms
# Speed: 1.7ms preprocess, 17.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf
# 0: 384x640 2 persons, 8 cars, 16.9ms
# Speed: 1.8ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 17.1ms
# Speed: 1.7ms preprocess, 17.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 17.6ms
# Speed: 1.9ms preprocess, 17.6ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [121] Пропущено: пустое изображение или нет людей
#
# 0: 384x640 1 person, 7 cars, 10.8ms
# Speed: 1.1ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
